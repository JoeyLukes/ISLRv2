# %%
import numpy as np
import pandas as pd

import plotly.express as px
import matplotlib.pyplot as plt
import seaborn as sns

import statsmodels.api as sm

# %%
## Import Stock Market Data

## Import advertisting dataset
bikeshare = pd.read_csv('..\..\datasets\Bikeshare_hour.csv', index_col='instant')
display(bikeshare)
# Out:
#              dteday  season  yr  mnth  hr  holiday  weekday  workingday  \
# instant
# 1        2011-01-01       1   0     1   0        0        6           0
# 2        2011-01-01       1   0     1   1        0        6           0
# 3        2011-01-01       1   0     1   2        0        6           0
# 4        2011-01-01       1   0     1   3        0        6           0
# 5        2011-01-01       1   0     1   4        0        6           0
# ...             ...     ...  ..   ...  ..      ...      ...         ...
# 17375    2012-12-31       1   1    12  19        0        1           1
# 17376    2012-12-31       1   1    12  20        0        1           1
# 17377    2012-12-31       1   1    12  21        0        1           1
# 17378    2012-12-31       1   1    12  22        0        1           1
# 17379    2012-12-31       1   1    12  23        0        1           1
#
#          weathersit  temp   atemp   hum  windspeed  casual  registered  cnt
# instant
# ...

# %%
bikeshare[['yr', 'mnth', 'hr', 'weekday', 'workingday', 'holiday']] = bikeshare[['yr', 'mnth', 'hr', 'weekday', 'workingday', 'holiday']].astype('str')
bikeshare.drop(columns=['dteday', 'season', 'yr', 'holiday', 'weekday', 'temp', 'atemp', 'hum', 'windspeed', 'casual', 'registered'], inplace=True)
bikeshare.dtypes
# Out:
# mnth          object
# hr            object
# workingday    object
# weathersit     int64
# cnt            int64
# dtype: object

# %%
exog = bikeshare.drop(columns=['cnt'])
exog = pd.get_dummies(exog, columns=['mnth', 'hr', 'workingday'])
endog = bikeshare.cnt

exog = sm.add_constant(exog)

poisson_model = sm.GLM(endog, exog, faimly=sm.families.Poisson)

poisson_results = poisson_model.fit()

print(poisson_results.summary())
# Out:
#                  Generalized Linear Model Regression Results
# ...
# Dep. Variable:                    cnt   No. Observations:                17379
# Model:                            GLM   Df Residuals:                    17342
# Model Family:                Gaussian   Df Model:                           36
# Link Function:               identity   Scale:                          13271.
# Method:                          IRLS   Log-Likelihood:            -1.0713e+05
# Date:                Thu, 27 Apr 2023   Deviance:                   2.3013e+08
# Time:                        12:34:55   Pearson chi2:                 2.30e+08
# No. Iterations:                     3   Pseudo R-squ. (CS):             0.7727
# Covariance Type:            nonrobust
# ...
#                    coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------
# const         4.358e+13   9.65e+13      0.451      0.652   -1.46e+14    2.33e+14
# ...

# %%
import numpy as np
import pandas as pd

import plotly.express as px
import matplotlib.pyplot as plt
import seaborn as sns

import statsmodels.api as sm

from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

# %%
## Import advertisting dataset
auto = pd.read_csv('..\..\datasets\Auto 2.csv', index_col='Unnamed: 0')
display(auto)
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  year  \
# 1    18.0          8         307.0         130    3504          12.0    70
# 2    15.0          8         350.0         165    3693          11.5    70
# 3    18.0          8         318.0         150    3436          11.0    70
# 4    16.0          8         304.0         150    3433          12.0    70
# 5    17.0          8         302.0         140    3449          10.5    70
# ..    ...        ...           ...         ...     ...           ...   ...
# 393  27.0          4         140.0          86    2790          15.6    82
# 394  44.0          4          97.0          52    2130          24.6    82
# 395  32.0          4         135.0          84    2295          11.6    82
# 396  28.0          4         120.0          79    2625          18.6    82
# 397  31.0          4         119.0          82    2720          19.4    82
#
#      origin                       name
# ...

# %%
## Will use validation set approach
## Testing linear models using sklearn
## Creation of test and training sets with sklearn.train_test_split of 50%

## Doesn't like when you pass in a series of only one feature. Pushing to numpy array and reshaping
X = np.array(auto.horsepower).reshape(-1,1)
y = auto.mpg

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=42)

reg = LinearRegression().fit(X_train, y_train)

train_preds = reg.predict(X_train)

print(f'Training MSE: {mean_squared_error(y_train, train_preds)}')

test_preds = reg.predict(X_test)

print(f'Training MSE: {mean_squared_error(y_test, test_preds)}')
# Out:
# Training MSE: 23.16172919929368
# Training MSE: 25.573878189684393

# %%
## Perform the same thing with Quadratic Regression

## Doesn't like when you pass in a series of only one feature. Pushing to numpy array and reshaping
X = np.array(auto.horsepower).reshape(-1,1)
y = auto.mpg

## Add Polynomial Features
poly = PolynomialFeatures(2)
X = poly.fit_transform(X)

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=42)

reg = LinearRegression().fit(X_train, y_train)

train_preds = reg.predict(X_train)

print(f'Training MSE: {mean_squared_error(y_train, train_preds)}')

test_preds = reg.predict(X_test)

print(f'Training MSE: {mean_squared_error(y_test, test_preds)}')
# Out:
# Training MSE: 16.839716144803923
# Training MSE: 22.21802005003384

# %%
## Perform the same thing with Cubic Regression

## Doesn't like when you pass in a series of only one feature. Pushing to numpy array and reshaping
X = np.array(auto.horsepower).reshape(-1,1)
y = auto.mpg

## Add Polynomial Features
poly = PolynomialFeatures(3)
X = poly.fit_transform(X)

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=42)

reg = LinearRegression().fit(X_train, y_train)

train_preds = reg.predict(X_train)

print(f'Training MSE: {mean_squared_error(y_train, train_preds)}')

test_preds = reg.predict(X_test)

print(f'Training MSE: {mean_squared_error(y_test, test_preds)}')
# Out:
# Training MSE: 16.5856028585659
# Training MSE: 22.66767543584181
